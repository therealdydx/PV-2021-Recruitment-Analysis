# %% [markdown]
# # Network Analysis - Venture Capital
#
# Script based off https://towardsdatascience.com/data-science-in-venture-capital-8c13ec0c8458

# %% [markdown]
# ### The Data
#
# - Data comes from Crunchbase
# - Focused on Singaporean funds and startups

# %% [markdown]
# ### Data Cleaning

# %%
# First, import all of the necessary libraries

import matplotlib.pyplot as plt # used for creating 

import networkx as nx # used for analysing the structure of networks

import pandas as pd # used for data manipulation and analysis

import numpy as np # used for creating n-dimensional arrays

from itertools import combinations # for creating combinations (nCr)

import copy # used for deep copying

# %% [markdown]
# ### Importing Data
#
# We will now read two datasets.
#
# - df_investors includes the name of all VC funds headquartered in Singapore with at least 1 investment
# - In the case of VC funds, we include the few categories:VC, CVCs, Micro VCs, Family Offices and Venture Debt
# - df_startups  includes the name of all Singaporean startups with a total funding amount higher than SGD 500k, as well as the name of their investors
# - Here, we are limited as Crunchbase only allows for Top 5 Investors in a startup. Never mind, we make do with the limitations.

# %%
# Investors Dataset

# read the csv file of investors
df_investors = pd.read_csv("investors.csv")
print(len(df_investors)) # get a sense how many investors there are

# Startups Dataset
df_startups = pd.read_csv("companies.csv")
print(len(df_startups)) # get a sense how many startups there are
# Out:
# 302
# 971

# %% [markdown]
# ### Basic Data Exploration

# %%
# slicing the investors database so that we only get location and the name
df_investors = df_investors.iloc[:, [0,2]]

# now rename the column header to something a bit more palatable
df_investors = df_investors.rename(columns={"Organization/Person Name" : "Investors"})

df_investors.head()
# Out:
#             Investors                              Location
# 0  Wavemaker Partners  Singapore, Central Region, Singapore
# 1              Antler  Singapore, Central Region, Singapore
# 2             BEENEXT  Singapore, Central Region, Singapore
# 3          JAFCO Asia  Singapore, Central Region, Singapore
# 4                EDBI  Singapore, Central Region, Singapore

# %%
# we slice the startups database so we only get the relevant columns
df_startups = df_startups.iloc[:, [0, 19]]

# let's rename the column header to something a bit more palatable
df_startups = df_startups.rename(columns = {"Top 5 Investors" : "Investors", "Organization Name" : "Organization"})

df_startups.head()
# Out:
#            Organization                                          Investors
# 0                   Sea  Tencent Holdings, General Atlantic, Hillhouse ...
# 1     Funding Societies  Sequoia Capital India, Line Corporation, Alpha...
# 2             Carousell  Naver, Sequoia Capital India, 500 Startups, Ra...
# 3     LongHash Ventures                  HashKey Capital, Fenbushi Capital
# 4  Grab Financial Group  GGV Capital, Flourish Ventures, Arbor Ventures...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Because the column "Investors" in the df_startups dataset includes all investors that invest in the startups, i.e. a Singaporean startup may have Japanese investors, we want to filter this so that the df_startups dataset only has Singaporean VCs

# %%
# extract the investor column from the df_startups, and convert the series into a list
# afterwards, the index for the new dataframe is based off the startups
# stack by column instead of row, and then reset index to create a new index column

# so we want to drop rows whereby a startup has NA investors (logging errors of Crunchbase)
df_startups = df_startups.dropna(subset = ['Investors'])

# create dictionary of investors
sg_startups = pd.DataFrame(df_startups['Investors'])
sg_investors = list(df_investors['Investors'])


# can try a join later
for row in sg_startups['Investors']:
    row = row.split(', ')
    row = list(row)
    new_row = copy.deepcopy(row)
    
    for i in row:
        if i not in sg_investors:
            new_row.remove(i)
            #sg_startups = sg_startups[sg_startups['Investors']].replace({i, np.nan})
            
    newlist = list()
    print(new_row)
    newlist.append(new_row)
    print(newlist)

    #sg_startups = sg_startups['Investors'].replace(row, new_row)
print(newlist)
# sg_startups = sg_startups.dropna(subset = ['Investors'])
# sg_startups
# Out:
# []
# [[]]
# []
# [[]]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# ['Arbor Ventures', 'K3 Ventures']
# [['Arbor Ventures', 'K3 Ventures']]
# []
# [[]]
# []
# [[]]
# ['Antler']
# [['Antler']]
# []
# [[]]
# ['Insignia Ventures Partners', 'Golden Gate']
# [['Insignia Ventures Partners', 'Golden Gate']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Monk’s Hill Ventures', 'Golden Gate']
# [['Monk’s Hill Ventures', 'Golden Gate']]
# []
# [[]]
# ['Openspace Ventures', 'EDBI']
# [['Openspace Ventures', 'EDBI']]
# []
# [[]]
# ['Singapore Exchange Limited']
# [['Singapore Exchange Limited']]
# []
# [[]]
# ['iGlobe Partners', 'EDBI']
# [['iGlobe Partners', 'EDBI']]
# ['January Capital']
# [['January Capital']]
# []
# [[]]
# ['BEENEXT']
# [['BEENEXT']]
# ['Nodex Capital']
# [['Nodex Capital']]
# []
# [[]]
# []
# [[]]
# ['Vickers Venture Partners']
# [['Vickers Venture Partners']]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'Singapore Angel Network']
# [['Wavemaker Partners', 'Singapore Angel Network']]
# []
# [[]]
# ['Vickers Venture Partners']
# [['Vickers Venture Partners']]
# []
# [[]]
# ['Insignia Ventures Partners']
# [['Insignia Ventures Partners']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['SeedPlus', 'Golden Gate', 'EV Growth']
# [['SeedPlus', 'Golden Gate', 'EV Growth']]
# []
# [[]]
# []
# [[]]
# ['Vertex Ventures Southeast Asia & India', 'Decacorn Capital', 'SMRT Ventures']
# [['Vertex Ventures Southeast Asia & India', 'Decacorn Capital', 'SMRT Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Singapore Angel Network']
# [['Singapore Angel Network']]
# []
# [[]]
# []
# [[]]
# ['SGInnovate']
# [['SGInnovate']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['EDBI', 'Kamet Capital Partners']
# [['EDBI', 'Kamet Capital Partners']]
# ['Golden Gate', 'Openspace Ventures']
# [['Golden Gate', 'Openspace Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Qualgro VC']
# [['Qualgro VC']]
# []
# [[]]
# []
# [[]]
# ['Monk’s Hill Ventures', 'Golden Equator Ventures']
# [['Monk’s Hill Ventures', 'Golden Equator Ventures']]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'BANSEA']
# [['Wavemaker Partners', 'BANSEA']]
# []
# [[]]
# ['Openspace Ventures', 'EDBI']
# [['Openspace Ventures', 'EDBI']]
# ['Seeds Capital']
# [['Seeds Capital']]
# ['August One', 'Spring SEEDS Capital']
# [['August One', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# ['GTR Ventures']
# [['GTR Ventures']]
# []
# [[]]
# ['Seeds Capital']
# [['Seeds Capital']]
# ['Genesis Alternative Ventures']
# [['Genesis Alternative Ventures']]
# ['Openspace Ventures', 'Singtel Innov8']
# [['Openspace Ventures', 'Singtel Innov8']]
# []
# [[]]
# ['Cardinal Capital']
# [['Cardinal Capital']]
# ['Arbor Ventures']
# [['Arbor Ventures']]
# ['Golden Gate', 'Wavemaker Partners', 'Openspace Ventures']
# [['Golden Gate', 'Wavemaker Partners', 'Openspace Ventures']]
# ['DSG Consumer Partners', 'Openspace Ventures']
# [['DSG Consumer Partners', 'Openspace Ventures']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['United Overseas Bank']
# [['United Overseas Bank']]
# []
# [[]]
# []
# [[]]
# ['Antler']
# [['Antler']]
# ['Heritas Capital Management', 'Capikris Foundation']
# [['Heritas Capital Management', 'Capikris Foundation']]
# ['Openspace Ventures', 'Seeds Capital', 'Jungle Ventures']
# [['Openspace Ventures', 'Seeds Capital', 'Jungle Ventures']]
# ['Openspace Ventures']
# [['Openspace Ventures']]
# ['Openspace Ventures']
# [['Openspace Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['NGC Ventures']
# [['NGC Ventures']]
# ['SGInnovate']
# [['SGInnovate']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Golden Equator Ventures', 'Wavemaker Partners']
# [['Golden Equator Ventures', 'Wavemaker Partners']]
# []
# [[]]
# ['Insignia Ventures Partners']
# [['Insignia Ventures Partners']]
# []
# [[]]
# ['Fintonia Group']
# [['Fintonia Group']]
# ['Monk’s Hill Ventures', 'K3 Ventures', 'Genesis Alternative Ventures']
# [['Monk’s Hill Ventures', 'K3 Ventures', 'Genesis Alternative Ventures']]
# []
# [[]]
# ['EDBI', 'Far East Ventures']
# [['EDBI', 'Far East Ventures']]
# []
# [[]]
# []
# [[]]
# ['United Overseas Bank']
# [['United Overseas Bank']]
# []
# [[]]
# ['Seeds Capital', 'Jungle Ventures']
# [['Seeds Capital', 'Jungle Ventures']]
# ['BEENEXT', 'Qualgro VC']
# [['BEENEXT', 'Qualgro VC']]
# []
# [[]]
# ['Golden Gate', 'SPH Media Fund']
# [['Golden Gate', 'SPH Media Fund']]
# []
# [[]]
# ['Wavemaker Partners', 'Singapore Exchange Limited', 'Jungle Ventures', 'Spring SEEDS Capital']
# [['Wavemaker Partners', 'Singapore Exchange Limited', 'Jungle Ventures', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# ['Golden Equator Ventures', 'Vertex Ventures Southeast Asia & India']
# [['Golden Equator Ventures', 'Vertex Ventures Southeast Asia & India']]
# ['Seeds Capital']
# [['Seeds Capital']]
# []
# [[]]
# ['Atlas Ventures', 'TNB Ventures']
# [['Atlas Ventures', 'TNB Ventures']]
# ['Spiral Ventures']
# [['Spiral Ventures']]
# []
# [[]]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# ['Marvelstone Group']
# [['Marvelstone Group']]
# ['Insignia Ventures Partners']
# [['Insignia Ventures Partners']]
# ['Wavemaker Partners', 'Atlas Ventures']
# [['Wavemaker Partners', 'Atlas Ventures']]
# []
# [[]]
# ['Wavemaker Partners', 'August One', 'Spring SEEDS Capital']
# [['Wavemaker Partners', 'August One', 'Spring SEEDS Capital']]
# []
# [[]]
# ['Kamet Capital Partners', 'Makara Capital']
# [['Kamet Capital Partners', 'Makara Capital']]
# []
# [[]]
# ['Insignia Ventures Partners', 'Wavemaker Partners', 'Seeds Capital']
# [['Insignia Ventures Partners', 'Wavemaker Partners', 'Seeds Capital']]
# ['Signum Capital']
# [['Signum Capital']]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# ['Spiral Ventures']
# [['Spiral Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Tanglin Venture Partners']
# [['Tanglin Venture Partners']]
# ['SeedPlus']
# [['SeedPlus']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Antler', '500 Durians']
# [['Antler', '500 Durians']]
# []
# [[]]
# []
# [[]]
# ['SGInnovate', 'August One']
# [['SGInnovate', 'August One']]
# []
# [[]]
# ['Cocoon Capital']
# [['Cocoon Capital']]
# []
# [[]]
# ['Vickers Venture Partners']
# [['Vickers Venture Partners']]
# []
# [[]]
# ['Antler']
# [['Antler']]
# []
# [[]]
# ['Vickers Venture Partners']
# [['Vickers Venture Partners']]
# []
# [[]]
# ['Insignia Ventures Partners', 'Wavemaker Partners']
# [['Insignia Ventures Partners', 'Wavemaker Partners']]
# ['Seeds Capital', 'Heritas Capital Management']
# [['Seeds Capital', 'Heritas Capital Management']]
# ['Saison Capital']
# [['Saison Capital']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['SGInnovate', 'MassMutual Ventures Southeast Asia (MMV SEA)', 'Cocoon Capital']
# [['SGInnovate', 'MassMutual Ventures Southeast Asia (MMV SEA)', 'Cocoon Capital']]
# ['Jungle Ventures', 'Qualgro VC', 'Sistema Asia Capital']
# [['Jungle Ventures', 'Qualgro VC', 'Sistema Asia Capital']]
# []
# [[]]
# ['SGInnovate', 'Quest Ventures', 'Mojo Partners']
# [['SGInnovate', 'Quest Ventures', 'Mojo Partners']]
# ['Monk’s Hill Ventures', 'Wavemaker Partners']
# [['Monk’s Hill Ventures', 'Wavemaker Partners']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['SGInnovate']
# [['SGInnovate']]
# []
# [[]]
# []
# [[]]
# ['Spring SEEDS Capital']
# [['Spring SEEDS Capital']]
# ['Saison Capital']
# [['Saison Capital']]
# []
# [[]]
# ['Arbor Ventures']
# [['Arbor Ventures']]
# []
# [[]]
# ['Genesis Alternative Ventures']
# [['Genesis Alternative Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Antler']
# [['Antler']]
# []
# [[]]
# ['Coent Venture Partners']
# [['Coent Venture Partners']]
# ['BioVeda Capital']
# [['BioVeda Capital']]
# []
# [[]]
# []
# [[]]
# ['Quest Ventures', 'SPH Media Fund', 'Neoteny Labs']
# [['Quest Ventures', 'SPH Media Fund', 'Neoteny Labs']]
# ['SGInnovate', 'Eight Mercatus']
# [['SGInnovate', 'Eight Mercatus']]
# []
# [[]]
# []
# [[]]
# ['Monk’s Hill Ventures']
# [['Monk’s Hill Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Seeds Capital', 'TRIREC', 'TNB AURA']
# [['Seeds Capital', 'TRIREC', 'TNB AURA']]
# []
# [[]]
# ['Quest Ventures', 'SPH Ventures']
# [['Quest Ventures', 'SPH Ventures']]
# []
# [[]]
# ['Singapore Angel Network']
# [['Singapore Angel Network']]
# ['Singtel Innov8']
# [['Singtel Innov8']]
# ['Openspace Ventures', 'SGInnovate']
# [['Openspace Ventures', 'SGInnovate']]
# ['Iterative']
# [['Iterative']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['Nodex Capital']
# [['Nodex Capital']]
# []
# [[]]
# ['Wavemaker Partners', 'Silicon Straits']
# [['Wavemaker Partners', 'Silicon Straits']]
# []
# [[]]
# ['Wavemaker Partners', 'Qualgro VC']
# [['Wavemaker Partners', 'Qualgro VC']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['Seeds Capital', 'Heritas Capital Management']
# [['Seeds Capital', 'Heritas Capital Management']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Tin Men Capital']
# [['Tin Men Capital']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['Iterative', 'RAPZO CAPITAL']
# [['Iterative', 'RAPZO CAPITAL']]
# []
# [[]]
# []
# [[]]
# ['RB Investments Pte. Ltd.', 'HH Investments VC']
# [['RB Investments Pte. Ltd.', 'HH Investments VC']]
# ['Quest Ventures', 'Raffle Venture Partners', 'J Capital']
# [['Quest Ventures', 'Raffle Venture Partners', 'J Capital']]
# []
# [[]]
# []
# [[]]
# ['Infocomm Investments']
# [['Infocomm Investments']]
# []
# [[]]
# []
# [[]]
# ['Insignia Ventures Partners']
# [['Insignia Ventures Partners']]
# []
# [[]]
# ['Antler', 'LongHash Ventures', 'NGC Ventures']
# [['Antler', 'LongHash Ventures', 'NGC Ventures']]
# []
# [[]]
# ['Seeds Capital', 'Alto Partners Multi-Family Office', 'January Capital']
# [['Seeds Capital', 'Alto Partners Multi-Family Office', 'January Capital']]
# []
# [[]]
# ['BEENEXT']
# [['BEENEXT']]
# []
# [[]]
# []
# [[]]
# ['Seeds Capital']
# [['Seeds Capital']]
# ['Signum Capital', 'Du Capital']
# [['Signum Capital', 'Du Capital']]
# ['SGInnovate', 'EDBI']
# [['SGInnovate', 'EDBI']]
# []
# [[]]
# ['JAFCO Asia', 'Singtel Innov8']
# [['JAFCO Asia', 'Singtel Innov8']]
# []
# [[]]
# ['TNF Ventures']
# [['TNF Ventures']]
# ['SeedPlus', 'Qualgro VC']
# [['SeedPlus', 'Qualgro VC']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Sysma Holdings']
# [['Sysma Holdings']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['SMRT Ventures', 'Get2Volume', 'Prestellar Ventures']
# [['SMRT Ventures', 'Get2Volume', 'Prestellar Ventures']]
# []
# [[]]
# []
# [[]]
# ['BEENEXT']
# [['BEENEXT']]
# ['K3 Ventures']
# [['K3 Ventures']]
# []
# [[]]
# ['SGInnovate', 'Decacorn Capital']
# [['SGInnovate', 'Decacorn Capital']]
# ['Antler', 'Cocoon Capital']
# [['Antler', 'Cocoon Capital']]
# ['UOB Venture']
# [['UOB Venture']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'iGlobe Partners', 'Crystal Horse Investments']
# [['Wavemaker Partners', 'iGlobe Partners', 'Crystal Horse Investments']]
# []
# [[]]
# []
# [[]]
# ['Marvelstone Group', 'Dymon Asia Ventures']
# [['Marvelstone Group', 'Dymon Asia Ventures']]
# ['KK Fund']
# [['KK Fund']]
# ['Golden Gate']
# [['Golden Gate']]
# ['VisVires New Protein']
# [['VisVires New Protein']]
# ['Antler']
# [['Antler']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['K3 Ventures']
# [['K3 Ventures']]
# ['GBCI Ventures']
# [['GBCI Ventures']]
# ['Insignia Ventures Partners', 'DSG Consumer Partners', 'Genesis Alternative Ventures']
# [['Insignia Ventures Partners', 'DSG Consumer Partners', 'Genesis Alternative Ventures']]
# ['IncuVest']
# [['IncuVest']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['BEENEXT']
# [['BEENEXT']]
# []
# [[]]
# []
# [[]]
# ['Tin Men Capital']
# [['Tin Men Capital']]
# ['Signum Capital']
# [['Signum Capital']]
# ['Golden Gate', 'Wavemaker Partners', 'TNB AURA']
# [['Golden Gate', 'Wavemaker Partners', 'TNB AURA']]
# ['DSG Consumer Partners']
# [['DSG Consumer Partners']]
# ['SGInnovate']
# [['SGInnovate']]
# ['Verge HealthTech Fund']
# [['Verge HealthTech Fund']]
# ['Spring SEEDS Capital', 'Innosight Ventures']
# [['Spring SEEDS Capital', 'Innosight Ventures']]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# []
# [[]]
# ['Openspace Ventures', 'K3 Ventures', 'Vertex Ventures Southeast Asia & India']
# [['Openspace Ventures', 'K3 Ventures', 'Vertex Ventures Southeast Asia & India']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['NGC Ventures']
# [['NGC Ventures']]
# ['YSS Capital', 'Bukit Timah Capital']
# [['YSS Capital', 'Bukit Timah Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# []
# [[]]
# ['HH Investments VC']
# [['HH Investments VC']]
# ['Wavemaker Partners', 'SGInnovate']
# [['Wavemaker Partners', 'SGInnovate']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Golden Equator Ventures', 'K3 Ventures']
# [['Golden Equator Ventures', 'K3 Ventures']]
# ['Iterative', 'PSA Unboxed', 'ComfortDelGro Capital Partners']
# [['Iterative', 'PSA Unboxed', 'ComfortDelGro Capital Partners']]
# []
# [[]]
# []
# [[]]
# ['Venturecraft Group']
# [['Venturecraft Group']]
# []
# [[]]
# ['Wavemaker Partners', 'EDBI']
# [['Wavemaker Partners', 'EDBI']]
# ['WPGrowth Ventures']
# [['WPGrowth Ventures']]
# []
# [[]]
# ['SGInnovate', 'Atlas Ventures']
# [['SGInnovate', 'Atlas Ventures']]
# ['NGC Ventures']
# [['NGC Ventures']]
# []
# [[]]
# ['Vertex Ventures Southeast Asia & India', 'BioVeda Capital', 'Spring SEEDS Capital']
# [['Vertex Ventures Southeast Asia & India', 'BioVeda Capital', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# ['Golden Gate', 'Wavemaker Partners', 'LionRock Capital']
# [['Golden Gate', 'Wavemaker Partners', 'LionRock Capital']]
# ['BEENEXT', 'TRIREC']
# [['BEENEXT', 'TRIREC']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Decacorn Capital', 'BANSEA']
# [['Decacorn Capital', 'BANSEA']]
# []
# [[]]
# []
# [[]]
# ['SeedPlus']
# [['SeedPlus']]
# ['SPH Ventures']
# [['SPH Ventures']]
# []
# [[]]
# ['SGInnovate', 'Elev8.VC']
# [['SGInnovate', 'Elev8.VC']]
# ['Rekanext']
# [['Rekanext']]
# []
# [[]]
# ['Golden Gate', 'Seeds Capital']
# [['Golden Gate', 'Seeds Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['DSG Consumer Partners']
# [['DSG Consumer Partners']]
# ['Jungle Ventures', 'LionRock Capital']
# [['Jungle Ventures', 'LionRock Capital']]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'Seeds Capital', 'Accelerasia Ventures']
# [['Wavemaker Partners', 'Seeds Capital', 'Accelerasia Ventures']]
# ['MassMutual Ventures Southeast Asia (MMV SEA)']
# [['MassMutual Ventures Southeast Asia (MMV SEA)']]
# ['Startup-O', 'Ready Ventures']
# [['Startup-O', 'Ready Ventures']]
# ['Seeds Capital']
# [['Seeds Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['Monk’s Hill Ventures']
# [['Monk’s Hill Ventures']]
# ['Golden Equator Ventures', 'Jungle Ventures', 'Life.SREDA', 'Spring SEEDS Capital']
# [['Golden Equator Ventures', 'Jungle Ventures', 'Life.SREDA', 'Spring SEEDS Capital']]
# ['RB Investments Pte. Ltd.', 'HH Investments VC']
# [['RB Investments Pte. Ltd.', 'HH Investments VC']]
# ['SGInnovate', 'August One']
# [['SGInnovate', 'August One']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Atlas Ventures']
# [['Atlas Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Cocoon Capital']
# [['Cocoon Capital']]
# []
# [[]]
# ['BEENEXT', 'SGInnovate']
# [['BEENEXT', 'SGInnovate']]
# ['BEENEXT', 'Atlas Ventures']
# [['BEENEXT', 'Atlas Ventures']]
# ['Wavemaker Partners', 'Expara Thailand']
# [['Wavemaker Partners', 'Expara Thailand']]
# ['DTRIBE Capital', 'Crystal Horse Investments', 'Innosight Ventures']
# [['DTRIBE Capital', 'Crystal Horse Investments', 'Innosight Ventures']]
# ['Insignia Ventures Partners', 'K3 Ventures', 'Quest Ventures']
# [['Insignia Ventures Partners', 'K3 Ventures', 'Quest Ventures']]
# ['K3 Ventures', 'Spring SEEDS Capital']
# [['K3 Ventures', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Alps Ventures']
# [['Alps Ventures']]
# []
# [[]]
# ['JAFCO Asia']
# [['JAFCO Asia']]
# []
# [[]]
# []
# [[]]
# ['Monk’s Hill Ventures', 'Seeds Capital', 'TNB AURA', '500 Durians']
# [['Monk’s Hill Ventures', 'Seeds Capital', 'TNB AURA', '500 Durians']]
# ['Venturecraft Group']
# [['Venturecraft Group']]
# []
# [[]]
# []
# [[]]
# ['SeedPlus', 'SGInnovate']
# [['SeedPlus', 'SGInnovate']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Expara IDM Ventures']
# [['Expara IDM Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['SGInnovate', 'August One']
# [['SGInnovate', 'August One']]
# ['August One', 'Spring SEEDS Capital']
# [['August One', 'Spring SEEDS Capital']]
# ['Du Capital']
# [['Du Capital']]
# ['Seeds Capital']
# [['Seeds Capital']]
# ['Iterative']
# [['Iterative']]
# []
# [[]]
# []
# [[]]
# ['Ruvento']
# [['Ruvento']]
# []
# [[]]
# []
# [[]]
# ['Cocoon Capital']
# [['Cocoon Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Singtel Innov8']
# [['Singtel Innov8']]
# []
# [[]]
# []
# [[]]
# ['TNB AURA']
# [['TNB AURA']]
# []
# [[]]
# []
# [[]]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['LongHash Ventures', 'NGC Ventures']
# [['LongHash Ventures', 'NGC Ventures']]
# ['Aglaia Family Office']
# [['Aglaia Family Office']]
# ['SGInnovate', 'August One']
# [['SGInnovate', 'August One']]
# ['EDBI']
# [['EDBI']]
# ['Seeds Capital', 'ZIG Ventures']
# [['Seeds Capital', 'ZIG Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['500 Durians']
# [['500 Durians']]
# ['Startup-O']
# [['Startup-O']]
# ['August One', 'Spring SEEDS Capital']
# [['August One', 'Spring SEEDS Capital']]
# []
# [[]]
# ['HATCHER+', 'Singapore Angel Network']
# [['HATCHER+', 'Singapore Angel Network']]
# ['LongHash Ventures']
# [['LongHash Ventures']]
# []
# [[]]
# ['Fintonia Group']
# [['Fintonia Group']]
# []
# [[]]
# []
# [[]]
# ['Quest Ventures']
# [['Quest Ventures']]
# ['Insignia Ventures Partners']
# [['Insignia Ventures Partners']]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'C31Ventures']
# [['Wavemaker Partners', 'C31Ventures']]
# []
# [[]]
# ['THYNK GROUP']
# [['THYNK GROUP']]
# ['Red Dot Ventures']
# [['Red Dot Ventures']]
# []
# [[]]
# ['Vertex Ventures Southeast Asia & India']
# [['Vertex Ventures Southeast Asia & India']]
# ['Seeds Capital']
# [['Seeds Capital']]
# []
# [[]]
# []
# [[]]
# ['Vertex Ventures Southeast Asia & India']
# [['Vertex Ventures Southeast Asia & India']]
# ['Seeds Capital', 'TRIVE']
# [['Seeds Capital', 'TRIVE']]
# []
# [[]]
# ['Wavemaker Partners', 'Seeds Capital', 'SGInnovate']
# [['Wavemaker Partners', 'Seeds Capital', 'SGInnovate']]
# ['Seeds Capital', 'HealthXCapital']
# [['Seeds Capital', 'HealthXCapital']]
# ['SeedPlus', 'Seeds Capital']
# [['SeedPlus', 'Seeds Capital']]
# []
# [[]]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Golden Equator Ventures', 'Golden Gate', 'Jungle Ventures']
# [['Golden Equator Ventures', 'Golden Gate', 'Jungle Ventures']]
# []
# [[]]
# ['BEENEXT', 'Alto Partners Multi-Family Office']
# [['BEENEXT', 'Alto Partners Multi-Family Office']]
# ['iGlobe Partners', 'Majuven']
# [['iGlobe Partners', 'Majuven']]
# []
# [[]]
# []
# [[]]
# ['SeedPlus']
# [['SeedPlus']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Tuas Capital Partners', '8capita Partners']
# [['Tuas Capital Partners', '8capita Partners']]
# ['GENIEE']
# [['GENIEE']]
# []
# [[]]
# ['iGlobe Partners', 'C31Ventures']
# [['iGlobe Partners', 'C31Ventures']]
# []
# [[]]
# ['Eudaimonia Capital']
# [['Eudaimonia Capital']]
# ['Get2Volume']
# [['Get2Volume']]
# ['DSG Consumer Partners', 'Wavemaker Partners']
# [['DSG Consumer Partners', 'Wavemaker Partners']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Seeds Capital', 'Biopath Ventures']
# [['Seeds Capital', 'Biopath Ventures']]
# ['Sirius Venture Capital']
# [['Sirius Venture Capital']]
# ['Golden Equator Ventures']
# [['Golden Equator Ventures']]
# ['IncuVest']
# [['IncuVest']]
# []
# [[]]
# ['TRIVE']
# [['TRIVE']]
# ['Singtel Innov8']
# [['Singtel Innov8']]
# []
# [[]]
# []
# [[]]
# ['Get2Volume']
# [['Get2Volume']]
# []
# [[]]
# ['Electric Sheep Capital']
# [['Electric Sheep Capital']]
# []
# [[]]
# ['Tin Men Capital']
# [['Tin Men Capital']]
# ['IncuVest']
# [['IncuVest']]
# []
# [[]]
# []
# [[]]
# ['SGInnovate']
# [['SGInnovate']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Expara IDM Ventures']
# [['Expara IDM Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Tin Men Capital']
# [['Tin Men Capital']]
# ['OWW Capital Partners']
# [['OWW Capital Partners']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# ['JP Asia Prime Capital']
# [['JP Asia Prime Capital']]
# ['Dymon Asia Ventures']
# [['Dymon Asia Ventures']]
# []
# [[]]
# []
# [[]]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['Spring SEEDS Capital']
# [['Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['BEENEXT']
# [['BEENEXT']]
# []
# [[]]
# ['Jungle Ventures', 'Singtel Innov8']
# [['Jungle Ventures', 'Singtel Innov8']]
# ['Quest Ventures']
# [['Quest Ventures']]
# []
# [[]]
# ['Red Dot Ventures']
# [['Red Dot Ventures']]
# ['Quest Ventures', 'Plug and Play Asia Pacific', 'SPH Media Fund']
# [['Quest Ventures', 'Plug and Play Asia Pacific', 'SPH Media Fund']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['EDBI']
# [['EDBI']]
# ['Aurum Investments']
# [['Aurum Investments']]
# ['TRIVE']
# [['TRIVE']]
# ['SPH Ventures']
# [['SPH Ventures']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# ['JAFCO Asia']
# [['JAFCO Asia']]
# []
# [[]]
# ['Life.SREDA']
# [['Life.SREDA']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Innosight Ventures']
# [['Innosight Ventures']]
# ['Seeds Capital', 'Quest Ventures']
# [['Seeds Capital', 'Quest Ventures']]
# ['Cocoon Capital']
# [['Cocoon Capital']]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['United Overseas Bank']
# [['United Overseas Bank']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Sirius Venture Capital']
# [['Sirius Venture Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['K3 Ventures', 'Vertex Ventures Southeast Asia & India']
# [['K3 Ventures', 'Vertex Ventures Southeast Asia & India']]
# ['MegaOne Ventures', 'Ruvento']
# [['MegaOne Ventures', 'Ruvento']]
# []
# [[]]
# []
# [[]]
# ['August One', 'Spring SEEDS Capital']
# [['August One', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['mDR Group']
# [['mDR Group']]
# []
# [[]]
# ['Triplestar Capital']
# [['Triplestar Capital']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# []
# [[]]
# []
# [[]]
# ['Far East Ventures']
# [['Far East Ventures']]
# []
# [[]]
# ['Cardinal Capital', 'TWIN CAPITAL ASSET MANAGEMENT']
# [['Cardinal Capital', 'TWIN CAPITAL ASSET MANAGEMENT']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Wavemaker Partners', 'SGInnovate']
# [['Wavemaker Partners', 'SGInnovate']]
# ['Get2Volume']
# [['Get2Volume']]
# []
# [[]]
# ['Triple P Capital']
# [['Triple P Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['TRIVE']
# [['TRIVE']]
# []
# [[]]
# ['Esco Ventures']
# [['Esco Ventures']]
# []
# [[]]
# ['Red Dot Ventures', 'Raffle Venture Partners']
# [['Red Dot Ventures', 'Raffle Venture Partners']]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# []
# [[]]
# []
# [[]]
# ['Verge HealthTech Fund']
# [['Verge HealthTech Fund']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['IncuVest']
# [['IncuVest']]
# []
# [[]]
# ['Wavemaker Partners', 'Ruvento']
# [['Wavemaker Partners', 'Ruvento']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['TNF Ventures']
# [['TNF Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Get2Volume']
# [['Get2Volume']]
# []
# [[]]
# ['iGlobe Partners']
# [['iGlobe Partners']]
# []
# [[]]
# ['TRIVE']
# [['TRIVE']]
# []
# [[]]
# []
# [[]]
# ['Puffer Ventures']
# [['Puffer Ventures']]
# ['Silicon Straits']
# [['Silicon Straits']]
# ['HATCHER+']
# [['HATCHER+']]
# []
# [[]]
# ['Hera Capital', 'Innosight Ventures']
# [['Hera Capital', 'Innosight Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Red Dot Ventures', 'Green Marine Capital']
# [['Red Dot Ventures', 'Green Marine Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['BEENEXT', 'Openspace Ventures', 'Jungle Ventures']
# [['BEENEXT', 'Openspace Ventures', 'Jungle Ventures']]
# ['IncuVest']
# [['IncuVest']]
# ['JAFCO Asia']
# [['JAFCO Asia']]
# []
# [[]]
# ['Get2Volume']
# [['Get2Volume']]
# ['Singtel Innov8', 'TNF Ventures']
# [['Singtel Innov8', 'TNF Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['TRIREC', 'Spring SEEDS Capital']
# [['TRIREC', 'Spring SEEDS Capital']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Golden Gate']
# [['Golden Gate']]
# []
# [[]]
# ['SeedPlus']
# [['SeedPlus']]
# ['Seeds Capital']
# [['Seeds Capital']]
# ['Get2Volume']
# [['Get2Volume']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['TNF Ventures']
# [['TNF Ventures']]
# ['Innosight Ventures']
# [['Innosight Ventures']]
# ['TNF Ventures']
# [['TNF Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Majuven']
# [['Majuven']]
# []
# [[]]
# ['SGInnovate', 'LuneX Ventures']
# [['SGInnovate', 'LuneX Ventures']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['KK Fund']
# [['KK Fund']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Infocomm Investments', 'Neoteny Labs']
# [['Infocomm Investments', 'Neoteny Labs']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Accel X']
# [['Accel X']]
# []
# [[]]
# ['Innosight Ventures']
# [['Innosight Ventures']]
# []
# [[]]
# []
# [[]]
# ['Red Dot Ventures']
# [['Red Dot Ventures']]
# []
# [[]]
# []
# [[]]
# ['IDM Venture Capital']
# [['IDM Venture Capital']]
# []
# [[]]
# []
# [[]]
# ['Kathrein Ventures']
# [['Kathrein Ventures']]
# []
# [[]]
# []
# [[]]
# ['IncuVest']
# [['IncuVest']]
# []
# [[]]
# ['Wavemaker Partners']
# [['Wavemaker Partners']]
# ['Frankel iCapital Holdings']
# [['Frankel iCapital Holdings']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Singtel Innov8']
# [['Singtel Innov8']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Jungle Ventures']
# [['Jungle Ventures']]
# []
# [[]]
# ['JAFCO Asia', 'EDBI']
# [['JAFCO Asia', 'EDBI']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Innosight Ventures']
# [['Innosight Ventures']]
# ['EDBI']
# [['EDBI']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Neoteny Labs', 'Silicon Straits']
# [['Neoteny Labs', 'Silicon Straits']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# ['Singtel Innov8']
# [['Singtel Innov8']]
# []
# [[]]
# ['UOB Venture', 'Green Dot Capital']
# [['UOB Venture', 'Green Dot Capital']]
# ['OWW Capital Partners', 'AsiaCommerce']
# [['OWW Capital Partners', 'AsiaCommerce']]
# []
# [[]]
# ['Spring SEEDS Capital', 'Sirius Angel Fund']
# [['Spring SEEDS Capital', 'Sirius Angel Fund']]
# []
# [[]]
# []
# [[]]
# []
# [[]]
# [[]]

# %%
# basically now there are two columns with an index column, so afterwards just rename the columns
df_startups.rename({0: 'Investors'}, axis = 1, inplace = True)
df_startups['Investors'] = df_startups["Investors"].str.lstrip()

# merging the datasets to get the singaporean investors
df = pd.merge(df_startups, df_investors, how = "outer")

# drops NA values, drops location after subsetting dataframe to only singaporean investors, and resets index
df = df[df["Location"] == "Singapore"].dropna().drop(["Location"], axis = 1).reset_index(drop = True)

# %% [markdown]
# Now exclude the startups with only one investor
