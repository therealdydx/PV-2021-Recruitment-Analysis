# %% [markdown]
# # Recruitment Analysis
#
# A simple script to test for anomalies within recruitment.

# %% [markdown]
# ### Importing the necessary libraries for this:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the necessary file:

# %%
recruitment = pd.read_csv("recruitment.csv")

# %% [markdown]
# ### Doing basic checks on the table:

# %%
recruitment.head()
# Out:
#    Tag Number Assesor A   Assesor B  \
# 0           1      Nich  Marcus Wan
# 1           2      Nich  Marcus Wan
# 2           3      Nich  Marcus Wan
# 3           4      Nich  Marcus Wan
# 4           5      Nich  Marcus Wan
#
#   1h) As of August 2021, what year of study would you be in?  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#   1i) Will you be graduating before Jun 2022?  \
# 0                                          No
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
#
#   1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season.  \
# 0                                            checked
# 1                                            checked
# 2                                            checked
# 3                                            checked
# 4                                            checked
#
#   1k) What other commitments might you have for the next 12 months? (ie CCA Clubs, Freelance work, etc)  \
# 0                                       None for now
# 1  Want to join Investment and Entrepeneurs socie...
# 2                                             None.
# 3                                                NIL
# 4  Vice President - Bridges for Enterprise\nPart-...
#
#   1l) Do you have any prior experience in the startup/VC space? Elaborate.  \
# 0                                                 No
# 1  Yes, when I was younger I played through diffe...
# 2                                                No.
# 3  Have ran a failed start-up. My team and I were...
# 4  Investment Intern - Saison Capital (Dec 2020 -...
#
#   1l Assesor A's Score (1-5)  1l Assessor B's Score (1-5)  ...  \
# 0                        0\n                            0  ...
# 1                        1\n                            1  ...
# 2                        0\n                            0  ...
# 3                          4                            4  ...
# 4                          5                            5  ...
#
#                2e Assesor A's Score (A-C) + comments  \
# 0  B+ - To be honest, it is a good enough answer ...
# 1  B - Abit of a deviation from my personal answe...
# 2          C - Not really the most analytical answer
# 3  B+ - To be honest, it is a good enough answer ...
# 4         A - Great justification for each component
#
#               2e Assessor B's Score (A-C) + comments  \
# 0  A - Answer is reasonable with adequate elabora...
# 1  B - Answer is ok, but elaboration does not jus...
# 2            C - Poor answer, with weak explaination
# 3  A - Answer is reasonable with adequate elabora...
# 4  A - Good answers. Elaboration shows clear unde...
#
#    2f) Who are 3 individuals in your network that you identify as unstoppable forces of nature? Why?  \
# 0  I believe that my father, friend (Andrew) and ...
# 1  One of my grandmothers because she came from n...
# 2                                             None.
# 3  My CCA president. He was someone whom complete...
# 4  Chia Jeng Yang (Principal, Saison Capital) : I...
#
#   2f Assesor A's Score (1-5) 2f Assessor B's Score (1-5)  \
# 0                          3                           3
# 1                          3                           3
# 2                          0                           0
# 3                          3                           3
# 4                          5                           5
#
#    2g) What is the probability of you travelling into space sometime in your life? How confident are you of your answer and why?   \
# 0  I believe given the speed of advancements Elon...
# 1  I don’t want to die on earth and I think it is...
# 2  80%. As technology advances, I believe that ev...
# 3  I belive it will happen within my lifetime. Es...
# 4  The probability of me travelling into space so...
#
#   2g Assesor A's Score (1-5) 2g Assessor B's Score (1-5)  \
# 0                          3                           3
# 1                          2                           3
# 2                          1                           2
# 3                          1                           2
# 4                          4                           4
#
#                          Assessor A Overall Comments  \
# 0  Answered the questions but could have develope...
# 1  Vague answers and generally an underwhelming a...
# 2                                      Little effort
# 3  Started strong with experiences but in general...
# 4  Great effort and a strong application from sta...
#
#                          Assessor B Overall Comments
# 0  Generally gave decent answers, but did not par...
# 1  Gave a mixture of poor to average answers. Way...
# 2  Short, generic answers with no/poor elaboratio...
# 3  Decent background in the start-up ecosystem, b...
# 4  Strong VC background and it shows in the quali...
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Now we aim to clean the table to remove unnecessary columns for easier viewing:

# %%
# dropping tag number, year of study, graduating
del recruitment['Tag Number']
del recruitment['1h) As of August 2021, what year of study would you be in?']
del recruitment['1i) Will you be graduating before Jun 2022?']

# %%
recruitment.head()
# Out:
#   Assesor A   Assesor B  \
# 0      Nich  Marcus Wan
# 1      Nich  Marcus Wan
# 2      Nich  Marcus Wan
# 3      Nich  Marcus Wan
# 4      Nich  Marcus Wan
#
#   1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season.  \
# 0                                            checked
# 1                                            checked
# 2                                            checked
# 3                                            checked
# 4                                            checked
#
#   1k) What other commitments might you have for the next 12 months? (ie CCA Clubs, Freelance work, etc)  \
# 0                                       None for now
# 1  Want to join Investment and Entrepeneurs socie...
# 2                                             None.
# 3                                                NIL
# 4  Vice President - Bridges for Enterprise\nPart-...
#
#   1l) Do you have any prior experience in the startup/VC space? Elaborate.  \
# 0                                                 No
# 1  Yes, when I was younger I played through diffe...
# 2                                                No.
# 3  Have ran a failed start-up. My team and I were...
# 4  Investment Intern - Saison Capital (Dec 2020 -...
#
#   1l Assesor A's Score (1-5)  1l Assessor B's Score (1-5)  \
# 0                        0\n                            0
# 1                        1\n                            1
# 2                        0\n                            0
# 3                          4                            4
# 4                          5                            5
#
#        2a) Why do you want to join Protege Ventures?  \
# 0  I have heard many good things from my friends ...
# 1  I am very much interested in the startup and i...
# 2  To broaden my perspective and gain an insight ...
# 3  Protégé Ventures would equip me with the neces...
# 4  "- Interested to develop my skill sets in the ...
#
#   2a Assesor A's Score (1-5)  2a Assesor B's Score (1-5)  ...  \
# 0                          3                           3  ...
# 1                          1                           2  ...
# 2                          1                           1  ...
# 3                          3                           4  ...
# 4                          5                           5  ...
#
#                2e Assesor A's Score (A-C) + comments  \
# 0  B+ - To be honest, it is a good enough answer ...
# 1  B - Abit of a deviation from my personal answe...
# 2          C - Not really the most analytical answer
# 3  B+ - To be honest, it is a good enough answer ...
# 4         A - Great justification for each component
#
#               2e Assessor B's Score (A-C) + comments  \
# 0  A - Answer is reasonable with adequate elabora...
# 1  B - Answer is ok, but elaboration does not jus...
# 2            C - Poor answer, with weak explaination
# 3  A - Answer is reasonable with adequate elabora...
# 4  A - Good answers. Elaboration shows clear unde...
#
#    2f) Who are 3 individuals in your network that you identify as unstoppable forces of nature? Why?  \
# 0  I believe that my father, friend (Andrew) and ...
# 1  One of my grandmothers because she came from n...
# 2                                             None.
# 3  My CCA president. He was someone whom complete...
# 4  Chia Jeng Yang (Principal, Saison Capital) : I...
#
#   2f Assesor A's Score (1-5) 2f Assessor B's Score (1-5)  \
# 0                          3                           3
# 1                          3                           3
# 2                          0                           0
# 3                          3                           3
# 4                          5                           5
#
#    2g) What is the probability of you travelling into space sometime in your life? How confident are you of your answer and why?   \
# 0  I believe given the speed of advancements Elon...
# 1  I don’t want to die on earth and I think it is...
# 2  80%. As technology advances, I believe that ev...
# 3  I belive it will happen within my lifetime. Es...
# 4  The probability of me travelling into space so...
#
#   2g Assesor A's Score (1-5) 2g Assessor B's Score (1-5)  \
# 0                          3                           3
# 1                          2                           3
# 2                          1                           2
# 3                          1                           2
# 4                          4                           4
#
#                          Assessor A Overall Comments  \
# 0  Answered the questions but could have develope...
# 1  Vague answers and generally an underwhelming a...
# 2                                      Little effort
# 3  Started strong with experiences but in general...
# 4  Great effort and a strong application from sta...
#
#                          Assessor B Overall Comments
# 0  Generally gave decent answers, but did not par...
# 1  Gave a mixture of poor to average answers. Way...
# 2  Short, generic answers with no/poor elaboratio...
# 3  Decent background in the start-up ecosystem, b...
# 4  Strong VC background and it shows in the quali...
#
# [5 rows x 30 columns]

# %% [markdown]
# #### We check for those that have not checked for the commitments section:

# %%
# first let me check what is the data type for the column
recruitment['1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season.'].dtype

# so it is a string basically, okay
# Out:
# dtype('O')

# %%
unavailable = recruitment.loc[recruitment['1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season.'] != 'checked']
unavailable
# Out:
# Empty DataFrame
# Columns: [Assesor A, Assesor B, 1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season., 1k) What other commitments might you have for the next 12 months? (ie CCA Clubs, Freelance work, etc), 1l) Do you have any prior experience in the startup/VC space? Elaborate., 1l Assesor A's Score (1-5), 1l Assessor B's Score (1-5), 2a) Why do you want to join Protege Ventures?, 2a Assesor A's Score (1-5), 2a Assesor B's Score (1-5), 2b) From the above list, which startup are you most likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons., 2b Assesor A's Score (1-5), 2b Assessor B's Score (1-5), 2c) From the same list, which startup are you least likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons., 2c Assesor A's Score (1-5), 2c Assessor B's Score (1-5), 2d) Share with us some skill(s) (preferably one that is relevant to Protégé Ventures) that you are confident in. Feel free to include a link to some of your previous works (if any)., 2d Assesor A's Score (A-C) + comments, 2d Assessor B's Score (A-C) + comments, 2e) What do you think is the most important question VCs should ask? Why?, 2e Assesor A's Score (A-C) + comments, 2e Assessor B's Score (A-C) + comments, 2f) Who are 3 individuals in your network that you identify as unstoppable forces of nature? Why?, 2f Assesor A's Score (1-5), 2f Assessor B's Score (1-5), 2g) What is the probability of you travelling into space sometime in your life? How confident are you of your answer and why? , 2g Assesor A's Score (1-5), 2g Assessor B's Score (1-5), Assessor A Overall Comments, Assessor B Overall Comments]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# #### Since everyone can commit to PV, this column is also unnecessary, and can be removed to save columns, together with the next column:

# %%
del recruitment['1j) Should you be accepted into Protege Ventures, would you be able to commit to sessions on a weekly basis for the next 12 months? Sessions will be suspended during exam season.']
del recruitment['1k) What other commitments might you have for the next 12 months? (ie CCA Clubs, Freelance work, etc)']

# %%
recruitment.head()
# Out:
#   Assesor A   Assesor B  \
# 0      Nich  Marcus Wan
# 1      Nich  Marcus Wan
# 2      Nich  Marcus Wan
# 3      Nich  Marcus Wan
# 4      Nich  Marcus Wan
#
#   1l) Do you have any prior experience in the startup/VC space? Elaborate.  \
# 0                                                 No
# 1  Yes, when I was younger I played through diffe...
# 2                                                No.
# 3  Have ran a failed start-up. My team and I were...
# 4  Investment Intern - Saison Capital (Dec 2020 -...
#
#   1l Assesor A's Score (1-5)  1l Assessor B's Score (1-5)  \
# 0                        0\n                            0
# 1                        1\n                            1
# 2                        0\n                            0
# 3                          4                            4
# 4                          5                            5
#
#        2a) Why do you want to join Protege Ventures?  \
# 0  I have heard many good things from my friends ...
# 1  I am very much interested in the startup and i...
# 2  To broaden my perspective and gain an insight ...
# 3  Protégé Ventures would equip me with the neces...
# 4  "- Interested to develop my skill sets in the ...
#
#   2a Assesor A's Score (1-5)  2a Assesor B's Score (1-5)  \
# 0                          3                           3
# 1                          1                           2
# 2                          1                           1
# 3                          3                           4
# 4                          5                           5
#
#   2b) From the above list, which startup are you most likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons.  \
# 0  Personally, i would recommend Polybee, a deep ...
# 1  Probably polybee as it tackles a problem that ...
# 2  Whizz mobility. In view of the covid-19 situat...
# 3  Polybee would be the best option to invest int...
# 4  Friz - Neobank for freelancers and digital ent...
#
#   2b Assesor A's Score (1-5)  ...  \
# 0                          2  ...
# 1                          1  ...
# 2                          1  ...
# 3                          2  ...
# 4                          4  ...
#
#                2e Assesor A's Score (A-C) + comments  \
# 0  B+ - To be honest, it is a good enough answer ...
# 1  B - Abit of a deviation from my personal answe...
# 2          C - Not really the most analytical answer
# 3  B+ - To be honest, it is a good enough answer ...
# 4         A - Great justification for each component
#
#               2e Assessor B's Score (A-C) + comments  \
# 0  A - Answer is reasonable with adequate elabora...
# 1  B - Answer is ok, but elaboration does not jus...
# 2            C - Poor answer, with weak explaination
# 3  A - Answer is reasonable with adequate elabora...
# 4  A - Good answers. Elaboration shows clear unde...
#
#   2f) Who are 3 individuals in your network that you identify as unstoppable forces of nature? Why?  \
# 0  I believe that my father, friend (Andrew) and ...
# 1  One of my grandmothers because she came from n...
# 2                                             None.
# 3  My CCA president. He was someone whom complete...
# 4  Chia Jeng Yang (Principal, Saison Capital) : I...
#
#    2f Assesor A's Score (1-5) 2f Assessor B's Score (1-5)  \
# 0                           3                           3
# 1                           3                           3
# 2                           0                           0
# 3                           3                           3
# 4                           5                           5
#
#   2g) What is the probability of you travelling into space sometime in your life? How confident are you of your answer and why?   \
# 0  I believe given the speed of advancements Elon...
# 1  I don’t want to die on earth and I think it is...
# 2  80%. As technology advances, I believe that ev...
# 3  I belive it will happen within my lifetime. Es...
# 4  The probability of me travelling into space so...
#
#   2g Assesor A's Score (1-5) 2g Assessor B's Score (1-5)  \
# 0                          3                           3
# 1                          2                           3
# 2                          1                           2
# 3                          1                           2
# 4                          4                           4
#
#                          Assessor A Overall Comments  \
# 0  Answered the questions but could have develope...
# 1  Vague answers and generally an underwhelming a...
# 2                                      Little effort
# 3  Started strong with experiences but in general...
# 4  Great effort and a strong application from sta...
#
#                          Assessor B Overall Comments
# 0  Generally gave decent answers, but did not par...
# 1  Gave a mixture of poor to average answers. Way...
# 2  Short, generic answers with no/poor elaboratio...
# 3  Decent background in the start-up ecosystem, b...
# 4  Strong VC background and it shows in the quali...
#
# [5 rows x 28 columns]

# %% [markdown]
# #### We need to clean up the table, so let's check what the type of the scores is, and change it to integers:

# %%
# find a random variable
variable = recruitment.iloc[0, [3]]
variable.dtype
# Out:
# dtype('O')

# %%
# now we clean for all the columns that have scores present in them

# firstly we start by creating a column list with the relevant numbers needed
column_list = [3, 4, 6, 7, 9, 10, 12, 13, 21, 22, 24, 25]

# now loop through the column:
for index in column_list:
    
    # loop through each cell in each column
    for i, row_value in recruitment.iloc[:, [index]].iterrows():
        
        # change the values to strings so that you can remove extra comments
        recruitment.iloc[i, [index]] = recruitment.iloc[i, [index]].astype(str)
        
        # now remove any newlines from the cells
        recruitment.iloc[i, [index]] = recruitment.iloc[i, [index]].replace('\n','', regex=True)
        
        # because some scores have ranknigs attached to them, i.e. applicant 67: 2: I don't see much .... score
        # so we have to remove this, by taking the first score attached, i.e. take 2 and filter out the rest
        recruitment.iloc[i, [index]] = recruitment.iloc[i, [index]].str[:1]

# %%
# convert the strings into integers because it doesn't work by iloc somehow    
recruitment[recruitment.columns[column_list]] = recruitment[recruitment.columns[column_list]].apply(pd.to_numeric, errors = 'coerce')

# %%
recruitment.tail()
# Out:
#           Assesor A     Assesor B  \
# 63       Justin Peh      Noel Tan
# 64  Yap Tzi Richard  Wong Xin Hui
# 65  Yap Tzi Richard  Wong Xin Hui
# 66  Yap Tzi Richard  Wong Xin Hui
# 67  Yap Tzi Richard  Wong Xin Hui
#
#    1l) Do you have any prior experience in the startup/VC space? Elaborate.  \
# 63  My only tangible experience was interning at a...
# 64                          Pitching my startup to VC
# 65                                                 No
# 66  Active in multiple past startup competitions a...
# 67                                                 No
#
#     1l Assesor A's Score (1-5)  1l Assessor B's Score (1-5)  \
# 63                           4                            3
# 64                           1                            2
# 65                           0                            0
# 66                           1                            3
# 67                           0                            0
#
#         2a) Why do you want to join Protege Ventures?  \
# 63  After encouragement from one of my strategic m...
# 64                             Can launch my startup
# 65                                                ...
# 66  I am keen to learn more about the VC and inves...
# 67  I am looking at pivoting my career into Ventur...
#
#     2a Assesor A's Score (1-5)  2a Assesor B's Score (1-5)  \
# 63                           5                           4
# 64                           1                           1
# 65                           0                           0
# 66                           2                           5
# 67                           0                           1
#
#    2b) From the above list, which startup are you most likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons.  \
# 63  I would recommend Whizz after looking at the f...
# 64  3. No1 women more health conscious. No.2 able ...
# 65                                                ...
# 66  Polybee.\n\n1. Polybee is very clear in its mi...
# 67  Polybee.\nThought process:\n- I start with the...
#
#     2b Assesor A's Score (1-5)  ...  \
# 63                           4  ...
# 64                           0  ...
# 65                           0  ...
# 66                           3  ...
# 67                           3  ...
#
#                 2e Assesor A's Score (A-C) + comments  \
# 63         A: answer is based on research on startups
# 64  C: Not the best answer and no effort at all in...
# 65                                                 C-
# 66  A: Good answer on the management team and he/s...
# 67  B+: Can’t refute this because that’s indeed th...
#
#    2e Assessor B's Score (A-C) + comments  \
# 63            b: reasonable explanation\n
# 64             B: ok but lack elaboration
# 65                                      C
# 66                   A: Team is important
# 67                        B: Answer is ok
#
#     2f) Who are 3 individuals in your network that you identify as unstoppable forces of nature? Why?  \
# 63  1. My good friend Elijah from SMU\nBelieve it ...
# 64  1.Mr. Tan Pee Teck effective leadership in lea...
# 65                                                ...
# 66  Mr Richard Koh - My mentor. I am blessed that ...
# 67  Unfortunately, I could only identify one - a f...
#
#     2f Assesor A's Score (1-5) 2f Assessor B's Score (1-5)  \
# 63                           5                           5
# 64                           1                           2
# 65                           0                           0
# 66                           5                           5
# 67                           1                           2
#
#    2g) What is the probability of you travelling into space sometime in your life? How confident are you of your answer and why?   \
# 63  Not very high probability. Yet, paradoxically,...
# 64  Not in my life time. It's only a concept. Ther...
# 65                                                ...
# 66  Exact probability I am not sure. But if given ...
# 67  100%, but subject to I am willing to pay the t...
#
#    2g Assesor A's Score (1-5) 2g Assessor B's Score (1-5)  \
# 63                          2                           4
# 64                          3                           2
# 65                          0                           0
# 66                          4                           5
# 67                          3                           5
#
#                           Assessor A Overall Comments  \
# 63  Someone with alot of passion and taking this a...
# 64  For the startup recommendations, the applicant...
# 65                                             Reject
# 66  Quality responses and good effort in his/her a...
# 67  Decent responses but some of them are incohere...
#
#                           Assessor B Overall Comments
# 63  Strong individual with good analysis and inter...
# 64  gave very short and concise answers; could hav...
# 65                                           reject\n
# 66  Put in effort for his application, gave qualit...
# 67  Put in effort for his application, gave decent...
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Now we try to split up each part, and create tables to store the average text count for each score for each question in a table:

# %%
question_one = recruitment.iloc[:, [0, 1, 2, 3, 4]]

# %%
question_two = recruitment.iloc[:, [0, 1, 5, 6, 7]]
question_two.head()
# Out:
#   Assesor A   Assesor B      2a) Why do you want to join Protege Ventures?  \
# 0      Nich  Marcus Wan  I have heard many good things from my friends ...
# 1      Nich  Marcus Wan  I am very much interested in the startup and i...
# 2      Nich  Marcus Wan  To broaden my perspective and gain an insight ...
# 3      Nich  Marcus Wan  Protégé Ventures would equip me with the neces...
# 4      Nich  Marcus Wan  "- Interested to develop my skill sets in the ...
#
#   2a Assesor A's Score (1-5)  2a Assesor B's Score (1-5)
# 0                          3                         3.0
# 1                          1                         2.0
# 2                          1                         1.0
# 3                          3                         4.0
# 4                          5                         5.0

# %%
question_three = recruitment.iloc[:, [0, 1, 8, 9, 10]]
question_three.head()
# Out:
#   Assesor A   Assesor B  \
# 0      Nich  Marcus Wan
# 1      Nich  Marcus Wan
# 2      Nich  Marcus Wan
# 3      Nich  Marcus Wan
# 4      Nich  Marcus Wan
#
#   2b) From the above list, which startup are you most likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons.  \
# 0  Personally, i would recommend Polybee, a deep ...
# 1  Probably polybee as it tackles a problem that ...
# 2  Whizz mobility. In view of the covid-19 situat...
# 3  Polybee would be the best option to invest int...
# 4  Friz - Neobank for freelancers and digital ent...
#
#   2b Assesor A's Score (1-5)  2b Assessor B's Score (1-5)
# 0                          2                          2.0
# 1                          1                          2.0
# 2                          1                          1.0
# 3                          2                          2.0
# 4                          4                          3.0

# %%
question_four = recruitment.iloc[:, [0, 1, 11, 12, 13]]
question_four.head()
# Out:
#   Assesor A   Assesor B  \
# 0      Nich  Marcus Wan
# 1      Nich  Marcus Wan
# 2      Nich  Marcus Wan
# 3      Nich  Marcus Wan
# 4      Nich  Marcus Wan
#
#   2c) From the same list, which startup are you least likely to recommend to Protégé Ventures, for us to invest in? Share your thought process and justify with minimally 2 reasons.  \
# 0  I would be least likely to recommend Whizz Mob...
# 1  Usefriz because I don’t know how prevalent thi...
# 2  Noah. According to statistics in the Singapore...
# 3  Whizz mobility.\nThe last mile delivery has be...
# 4  Whizz Mobility - Delivery service for business...
#
#   2c Assesor A's Score (1-5)  2c Assessor B's Score (1-5)
# 0                          2                          2.0
# 1                          1                          1.0
# 2                          1                          2.0
# 3                          2                          1.0
# 4                          4                          4.0
